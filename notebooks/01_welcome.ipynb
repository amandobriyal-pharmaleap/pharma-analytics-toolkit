# %% [markdown]
# # Pharma Analytics Toolkit - Welcome
#
# This notebook introduces the toolkit and links to learning resources.
#
# - PharmaLeap Analytics Classes: https://www.pharmaleap.in/live-classes/pharma-analytics
# - PharmaLeap: https://www.pharmaleap.in

# %%
import pandas as pd

df = pd.read_csv('../data/sample_sales.csv')
df.head()
